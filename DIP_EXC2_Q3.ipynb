# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahraEk/Digital-Image-Proccesing/blob/main/DIP_EXC2_Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import Required libraries :

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# Q3_A :

# %%
#Read image
img = cv2.imread("drive/MyDrive/DIP_EXC2/Q3/Q3_img.jpg")

#Laplacian Mask
L = np.array([[0,-1,0],[-1, 4, -1],[0, -1, 0]])
laplacian_img = cv2.filter2D(img, -1, L)

#Sharping Mask
Sharp_img = img + laplacian_img

#Show image
horizontal_concat = np.concatenate((img, laplacian_img, Sharp_img), axis=1)
cv2_imshow(horizontal_concat)
print("Images from left to right : {Original, Laplacian, Sharp}")

#Save image
cv2.imwrite("drive/MyDrive/DIP_EXC2/Q3/Sharp_img.jpg", Sharp_img)
cv2.imwrite("drive/MyDrive/DIP_EXC2/Q3/Q3_A_img.jpg", horizontal_concat)
 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=1494x251 at 0x7F32C40F4AF0>
# Images from left to right : {Original, Laplacian, Sharp}

# %% [markdown]
# Q3_B :

# %%
#GaussianBlur Mask
L = 1/16* (np.array([[1, 2, 1],[2, 4, 2],[1, 2, 1]]))
blur_img= cv2.filter2D(img, -1, L)

#GMask
Gmask = img - blur_img

#UnSharp Mask
Unsharp_img = img + Gmask

#Show image
horizontal_concat1 = np.concatenate((img, blur_img), axis=1)
horizontal_concat2 = np.concatenate((Gmask, Unsharp_img), axis=1)
cv2_imshow(horizontal_concat1)
print("Images from left to right : {original, GaussianBlur}")
cv2_imshow(horizontal_concat2)
print("Images from left to right : {Gmask, UnSharp}")

#Save image
cv2.imwrite("drive/MyDrive/DIP_EXC2/Q3/Unsharp_img.jpg", Unsharp_img)
cv2.imwrite("drive/MyDrive/DIP_EXC2/Q3/Q3_B_img1.jpg", horizontal_concat1)
cv2.imwrite("drive/MyDrive/DIP_EXC2/Q3/Q3_B_img2.jpg", horizontal_concat2)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=996x251 at 0x7F32C40A3730>
# Images from left to right : {original, GaussianBlur}
# <PIL.Image.Image image mode=RGB size=996x251 at 0x7F32E9FF5EA0>
# Images from left to right : {Gmask, UnSharp}

# %% [markdown]
# Result Q3_A vs Q3_B :

# %%
horizontal_concat = np.concatenate((Sharp_img, Unsharp_img), axis=1)

#Convert to GrayScale
horizontal_concat_Gray = cv2.cvtColor(horizontal_concat,cv2.COLOR_BGR2GRAY)

#Show image
cv2_imshow(horizontal_concat)
print("Images from left to right : {Sharp, Unsharp}\n")
print("GrayScale:\n")
cv2_imshow(horizontal_concat_Gray)
print("Images from left to right : {Sharp, Unsharp}\n")

#Save image
cv2.imwrite("drive/MyDrive/DIP_EXC2/Q3/Sharp.vs.Unsharp.jpg", horizontal_concat)
cv2.imwrite("drive/MyDrive/DIP_EXC2/Q3/Sharp.vs.Unsharp_Gray.jpg", horizontal_concat_Gray)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=996x251 at 0x7F32BB217E20>
# Images from left to right : {Sharp, Unsharp}
#
# GrayScale:
# <PIL.Image.Image image mode=L size=996x251 at 0x7F32EAF10CA0>
# Images from left to right : {Sharp, Unsharp}
