# %% [markdown]
# <a href="https://colab.research.google.com/github/ZahraEk/Digital-Image-Proccesing/blob/main/DIP_EXC1_Q2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import Required libraries :

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# Q2 :

# %%
#read image
img = cv2.imread("drive/MyDrive/DIP_EXC1/Q2/img_Q2.png",0)

#center of circles
x1, y1 = 187, 78
x2, y2 = 233, 151
x3, y3 = 171, 158 
x4, y4 = 168, 190
x5, y5 = 196, 230

radius = 10

color1 = (255,255,255)
color2 = (204,204,204)

#draw white circles
cv2.circle(img, (x1, y1), radius, color1, 2)
cv2.circle(img, (x2, y2), radius, color1, 2)
cv2.circle(img, (x3, y3), radius, color1, 2)
cv2.circle(img, (x4, y4), radius, color1, 2)
cv2.circle(img, (x5, y5), radius, color1, 2)

"""
#draw gray circles
cv2.circle(img, (x1, y1), radius, color2, -1)
cv2.circle(img, (x2, y2), radius, color2, -1)
cv2.circle(img, (x3, y3), radius, color2, -1)
cv2.circle(img, (x4, y4), radius, color2, -1)
cv2.circle(img, (x5, y5), radius, color2, -1)
"""

#show image
cv2_imshow(img)

"""
#save image
cv2.imwrite('drive/MyDrive/DIP_EXC1/Q2/Q2_a_gray.png', img)
cv2.imwrite('drive/MyDrive/DIP_EXC1/Q2/Q2_a_rgb.png', img)
cv2.imwrite('drive/MyDrive/DIP_EXC1/Q2/Q2_b1.png', img)
cv2.imwrite('drive/MyDrive/DIP_EXC1/Q2/Q2_b2.png', img)
"""

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=430x330 at 0x7F0714F74280>
